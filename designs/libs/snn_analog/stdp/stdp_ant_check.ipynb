# %%
import os
import re
import sys
from pathlib import Path
import tempfile
import subprocess

magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name = "stdp"
path_to_dir = "/foss/designs/libs/snn_analog/stdp/"

gds_path = path_to_dir + f"{design_name}.gds"

    
magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell

# Se requiere la extracción previa para calcular las áreas de metal y difusión
extract do local
extract all

# Ejecución de la verificación de antena
antennacheck debug
puts "--- ANTENNA CHECK COMPLETED ---"
exit
"""

with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name

# Se eliminó la coma sobrante al final de la cadena de comando
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'"
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)


# --- PARSEO Y DETECCIÓN DE ERRORES ---

# Expresión regular para capturar líneas de violación reportadas por antennacheck
antenna_error_pattern = re.compile(r"(antenna ratio exceeded|antenna violation|failed antenna)", re.IGNORECASE)

violations = [line.strip() for line in magic_subproc_out.splitlines() if antenna_error_pattern.search(line)]

if violations:
    print(f"\n[ERROR] Se encontraron {len(violations)} violaciones de antena en '{design_name}':\n")
    for v in violations:
        print(f"  -> {v}")
    
    # Detener la ejecución del script con código de error
    sys.exit(1)
else:
    print(f"\n[SUCCESS] Succesfull antena verification for  '{design_name}'. No violations.")
# Out:
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "stdp".
# Reading "via_stack_a2e89513".
# Reading "c_route_c0d8624c".
# Reading "xm5".
# Reading "L_route_7418b0f0".
# Reading "L_route_f3c37f7c".
# Reading "L_route_fd8021c9".
# Reading "xm12".
# Reading "compass_1513e44c".
# Reading "L_route_7d1d6490".
# Reading "L_route_2a0d08f8".
# Reading "compass_7c30efbc".
# Reading "compass_d564bdc4".
# Reading "via_stack_a2e89513$7".
# Reading "straight_route_d6a45d2e".
# Reading "L_route_80b7825c".
# Reading "rectangle_e2d3d538".
# Reading "straight_route_912067d4".
# Reading "compass_7c30efbc$1".
# Reading "L_route_c02104a2".
# Reading "rectangle_a9fdc1e6".
# Reading "compass_2ca8eea5$1".
# Reading "xm4".
# Reading "L_route_02ccd910".
# Reading "L_route_47d51595".
# Reading "straight_route_627dacd5".
# Reading "rectangle_09b029e7$1".
# Reading "via_stack_a2e89513$1".
# Reading "L_route_a3d28efd".
# Reading "L_route_eecda21a".
# Reading "via_stack_a2e89513$8".
# Reading "c_route_74e2d13e".
# Reading "L_route_84b89d48".
# Reading "c_route_58d7b39c".
# Reading "straight_route_e98796db".
# Reading "straight_route_87d64758".
# Reading "L_route_473cd7a1".
# Reading "via_stack_a2e89513$11".
# Reading "via_stack_9a7c1b9a$1".
# Reading "straight_route_806dfc06".
# Reading "L_route_e80ba176".
# Reading "xm7".
# Reading "compass_a819ccbf".
# Reading "rectangle_09b029e7".
# Reading "via_stack_a2e89513$2".
# Reading "rectangle_d564bdc4".
# Reading "c_route_7f62e8aa".
# Reading "compass_09b029e7$1".
# Reading "xmcm_chain_4".
# Reading "compass_2ca8eea5".
# Reading "via_stack_a2e89513$9".
# Reading "c_route_d8df7a08".
# Reading "straight_route_d412d36f".
# Reading "L_route_de1ddc48".
# Reading "xm1".
# Reading "via_stack_9a7c1b9a".
# Reading "L_route_a4b8e0be".
# Reading "L_route_eb435deb".
# Reading "compass_de42ad8e".
# Reading "L_route_d08c40b4".
# Reading "via_stack_a2e89513$10".
# Reading "c_route_5d5d9dce".
# Reading "xmcm_chain_2".
# Reading "straight_route_b12ee564".
# Reading "cw".
# Reading "compass_b92fd4c8$1".
# Reading "via_stack_a2e89513$3".
# Reading "straight_route_1d1f080b".
# Reading "c_route_27a9af3f".
# Reading "straight_route_4f7b53c4".
# Reading "rectangle_7c30efbc$1".
# Reading "compass_e2d3d538".
# Reading "straight_route_278724c2".
# Reading "L_route_d7736fb3".
# Reading "c_route_ee66a350".
# Reading "compass_09b029e7".
# Reading "L_route_b110259d".
# Reading "L_route_a5af8734".
# Reading "rectangle_71fba8f9".
# Reading "L_route_36e59ea2".
# Reading "straight_route_0e3b015b".
# Reading "L_route_8d468e06".
# Reading "c_route_2c32f15c".
# Reading "rectangle_7c30efbc".
# Reading "rectangle_b92fd4c8".
# Reading "L_route_24694a7c".
# Reading "L_route_9fbd38b8".
# Reading "compass_71fba8f9".
# Reading "xmcm_chain_3".
# Reading "xm9".
# Reading "xmcm_1".
# Reading "compass_a9fdc1e6".
# Reading "c_route_907243ac".
# Reading "xm16".
# Reading "via_stack_a2e89513$4".
# Reading "via_stack_a2e89513$18".
# Reading "compass_d564bdc4$1".
# Reading "c_route_8d402972".
# Reading "straight_route_5d9b008b".
# Reading "L_route_78eb8817".
# Reading "c_route_51338640".
# Reading "L_route_5dfb3b8e".
# Reading "via_stack_a2e89513$20".
# Reading "compass_5f24ff68$1".
# Reading "L_route_bf2dc457".
# Reading "L_route_a26b7849".
# Reading "compass_5f24ff68".
# Reading "xm3".
# Reading "rectangle_a819ccbf".
# Reading "rectangle_5f24ff68$1".
# Reading "L_route_b70fb8b9".
# Reading "rectangle_2ca8eea5".
# Reading "c_route_827fc2f0".
# Reading "compass_71fba8f9$1".
# Reading "L_route_97c034e0".
# Reading "cpot".
# Reading "xmcm_chain_0".
# Reading "rectangle_de42ad8e".
# Reading "xm8".
# Reading "rectangle_d564bdc4$1".
# Reading "straight_route_40ea4316".
# Reading "L_route_f95e00f1".
# Reading "xm17".
# Reading "via_stack_a2e89513$5".
# Reading "rectangle_1513e44c".
# Reading "L_route_9c9fed4d".
# Reading "compass_b92fd4c8".
# Reading "L_route_250364aa".
# Reading "cdep".
# Reading "straight_route_dcd74ac0".
# Reading "via_stack_a2e89513$21".
# Reading "straight_route_dfafd98e".
# Reading "straight_route_d4eb442b".
# Reading "L_route_15a0f388".
# Reading "xm2".
# Reading "straight_route_bef7e062".
# Reading "rectangle_b92fd4c8$1".
# Reading "rectangle_5f24ff68".
# Reading "xmcm_chain_1".
# Reading "L_route_7fbace87".
# Reading "c_route_8c2c3aa6".
# Reading "rectangle_2ca8eea5$1".
# Reading "via_stack_a2e89513$6".
# Reading "rectangle_71fba8f9$1".
# Extracting via_stack_9a7c1b9a$1 into via_stack_9a7c1b9a$1.ext:
# Extracting compass_09b029e7$1 into compass_09b029e7$1.ext:
# Extracting rectangle_09b029e7$1 into rectangle_09b029e7$1.ext:
# Extracting compass_5f24ff68$1 into compass_5f24ff68$1.ext:
# Extracting rectangle_5f24ff68$1 into rectangle_5f24ff68$1.ext:
# Extracting compass_d564bdc4$1 into compass_d564bdc4$1.ext:
# Extracting rectangle_d564bdc4$1 into rectangle_d564bdc4$1.ext:
# Extracting compass_b92fd4c8$1 into compass_b92fd4c8$1.ext:
# Extracting rectangle_b92fd4c8$1 into rectangle_b92fd4c8$1.ext:
# Extracting via_stack_a2e89513 into via_stack_a2e89513.ext:
# Extracting L_route_fd8021c9 into L_route_fd8021c9.ext:
# Extracting L_route_c02104a2 into L_route_c02104a2.ext:
# Extracting L_route_473cd7a1 into L_route_473cd7a1.ext:
# Extracting L_route_de1ddc48 into L_route_de1ddc48.ext:
# Extracting via_stack_9a7c1b9a into via_stack_9a7c1b9a.ext:
# Extracting compass_7c30efbc$1 into compass_7c30efbc$1.ext:
# Extracting rectangle_7c30efbc$1 into rectangle_7c30efbc$1.ext:
# Extracting L_route_36e59ea2 into L_route_36e59ea2.ext:
# Extracting L_route_a26b7849 into L_route_a26b7849.ext:
# Extracting L_route_7fbace87 into L_route_7fbace87.ext:
# Extracting straight_route_912067d4 into straight_route_912067d4.ext:
# Extracting straight_route_0e3b015b into straight_route_0e3b015b.ext:
# Extracting via_stack_a2e89513$20 into via_stack_a2e89513$20.ext:
# Extracting xmcm_chain_1 into xmcm_chain_1.ext:
# Extracting straight_route_627dacd5 into straight_route_627dacd5.ext:
# Extracting L_route_eb435deb into L_route_eb435deb.ext:
# Extracting xmcm_chain_2 into xmcm_chain_2.ext:
# Extracting via_stack_a2e89513$21 into via_stack_a2e89513$21.ext:
# Extracting straight_route_e98796db into straight_route_e98796db.ext:
# Extracting c_route_5d5d9dce into c_route_5d5d9dce.ext:
# Extracting xm4 into xm4.ext:
# Extracting via_stack_a2e89513$11 into via_stack_a2e89513$11.ext:
# Extracting straight_route_d412d36f into straight_route_d412d36f.ext:
# Extracting straight_route_1d1f080b into straight_route_1d1f080b.ext:
# Extracting L_route_b110259d into L_route_b110259d.ext:
# Extracting via_stack_a2e89513$4 into via_stack_a2e89513$4.ext:
# Extracting xm3 into xm3.ext:
# Extracting xm9 into xm9.ext:
# Extracting L_route_d7736fb3 into L_route_d7736fb3.ext:
# Extracting straight_route_806dfc06 into straight_route_806dfc06.ext:
# Extracting L_route_f3c37f7c into L_route_f3c37f7c.ext:
# Extracting straight_route_d4eb442b into straight_route_d4eb442b.ext:
# Extracting straight_route_40ea4316 into straight_route_40ea4316.ext:
# Extracting xmcm_1 into xmcm_1.ext:
# Extracting via_stack_a2e89513$3 into via_stack_a2e89513$3.ext:
# Extracting L_route_eecda21a into L_route_eecda21a.ext:
# Extracting xm12 into xm12.ext:
# Extracting c_route_907243ac into c_route_907243ac.ext:
# Extracting c_route_27a9af3f into c_route_27a9af3f.ext:
# Extracting c_route_2c32f15c into c_route_2c32f15c.ext:
# Extracting c_route_8d402972 into c_route_8d402972.ext:
# Extracting c_route_51338640 into c_route_51338640.ext:
# Extracting c_route_827fc2f0 into c_route_827fc2f0.ext:
# Extracting c_route_7f62e8aa into c_route_7f62e8aa.ext:
# Extracting L_route_02ccd910 into L_route_02ccd910.ext:
# Extracting straight_route_b12ee564 into straight_route_b12ee564.ext:
# Extracting straight_route_4f7b53c4 into straight_route_4f7b53c4.ext:
# Extracting L_route_8d468e06 into L_route_8d468e06.ext:
# Extracting xmcm_chain_3 into xmcm_chain_3.ext:
# Extracting straight_route_5d9b008b into straight_route_5d9b008b.ext:
# Extracting xmcm_chain_0 into xmcm_chain_0.ext:
# Extracting via_stack_a2e89513$8 into via_stack_a2e89513$8.ext:
# Extracting c_route_74e2d13e into c_route_74e2d13e.ext:
# Extracting L_route_84b89d48 into L_route_84b89d48.ext:
# Extracting via_stack_a2e89513$5 into via_stack_a2e89513$5.ext:
# Extracting L_route_9c9fed4d into L_route_9c9fed4d.ext:
# Extracting L_route_47d51595 into L_route_47d51595.ext:
# Extracting xm16 into xm16.ext:
# Extracting via_stack_a2e89513$6 into via_stack_a2e89513$6.ext:
# Extracting cdep into cdep.ext:
# Extracting L_route_97c034e0 into L_route_97c034e0.ext:
# Extracting c_route_d8df7a08 into c_route_d8df7a08.ext:
# Extracting xmcm_chain_4 into xmcm_chain_4.ext:
# Extracting straight_route_87d64758 into straight_route_87d64758.ext:
# Extracting L_route_7418b0f0 into L_route_7418b0f0.ext:
# Extracting c_route_ee66a350 into c_route_ee66a350.ext:
# Extracting cw into cw.ext:
# Extracting straight_route_bef7e062 into straight_route_bef7e062.ext:
# Extracting xm2 into xm2.ext:
# Extracting L_route_15a0f388 into L_route_15a0f388.ext:
# Extracting xm1 into xm1.ext:
# Extracting via_stack_a2e89513$9 into via_stack_a2e89513$9.ext:
# Extracting c_route_58d7b39c into c_route_58d7b39c.ext:
# Extracting via_stack_a2e89513$1 into via_stack_a2e89513$1.ext:
# Extracting L_route_7d1d6490 into L_route_7d1d6490.ext:
# Extracting xm5 into xm5.ext:
# Extracting straight_route_dcd74ac0 into straight_route_dcd74ac0.ext:
# Extracting xm7 into xm7.ext:
# Extracting L_route_80b7825c into L_route_80b7825c.ext:
# Extracting straight_route_dfafd98e into straight_route_dfafd98e.ext:
# Extracting xm8 into xm8.ext:
# Extracting L_route_78eb8817 into L_route_78eb8817.ext:
# Extracting via_stack_a2e89513$2 into via_stack_a2e89513$2.ext:
# Extracting straight_route_d6a45d2e into straight_route_d6a45d2e.ext:
# Extracting via_stack_a2e89513$10 into via_stack_a2e89513$10.ext:
# Extracting L_route_2a0d08f8 into L_route_2a0d08f8.ext:
# Extracting via_stack_a2e89513$7 into via_stack_a2e89513$7.ext:
# Extracting L_route_a4b8e0be into L_route_a4b8e0be.ext:
# Extracting L_route_d08c40b4 into L_route_d08c40b4.ext:
# Extracting L_route_5dfb3b8e into L_route_5dfb3b8e.ext:
# Extracting xm17 into xm17.ext:
# Extracting c_route_c0d8624c into c_route_c0d8624c.ext:
# Extracting L_route_24694a7c into L_route_24694a7c.ext:
# Extracting L_route_bf2dc457 into L_route_bf2dc457.ext:
# Extracting c_route_8c2c3aa6 into c_route_8c2c3aa6.ext:
# Extracting L_route_250364aa into L_route_250364aa.ext:
# Extracting L_route_a3d28efd into L_route_a3d28efd.ext:
# Extracting straight_route_278724c2 into straight_route_278724c2.ext:
# Extracting L_route_b70fb8b9 into L_route_b70fb8b9.ext:
# Extracting cpot into cpot.ext:
# Extracting L_route_f95e00f1 into L_route_f95e00f1.ext:
# Extracting L_route_e80ba176 into L_route_e80ba176.ext:
# Extracting L_route_a5af8734 into L_route_a5af8734.ext:
# Extracting compass_7c30efbc into compass_7c30efbc.ext:
# Extracting rectangle_7c30efbc into rectangle_7c30efbc.ext:
# Extracting L_route_9fbd38b8 into L_route_9fbd38b8.ext:
# Extracting via_stack_a2e89513$18 into via_stack_a2e89513$18.ext:
# Extracting compass_09b029e7 into compass_09b029e7.ext:
# Extracting rectangle_09b029e7 into rectangle_09b029e7.ext:
# Extracting compass_b92fd4c8 into compass_b92fd4c8.ext:
# Extracting rectangle_b92fd4c8 into rectangle_b92fd4c8.ext:
# Extracting compass_d564bdc4 into compass_d564bdc4.ext:
# Extracting rectangle_d564bdc4 into rectangle_d564bdc4.ext:
# Extracting compass_5f24ff68 into compass_5f24ff68.ext:
# Extracting rectangle_5f24ff68 into rectangle_5f24ff68.ext:
# Extracting compass_e2d3d538 into compass_e2d3d538.ext:
# Extracting rectangle_e2d3d538 into rectangle_e2d3d538.ext:
# Extracting compass_71fba8f9 into compass_71fba8f9.ext:
# Extracting rectangle_71fba8f9 into rectangle_71fba8f9.ext:
# Extracting compass_a9fdc1e6 into compass_a9fdc1e6.ext:
# Extracting rectangle_a9fdc1e6 into rectangle_a9fdc1e6.ext:
# Extracting compass_2ca8eea5 into compass_2ca8eea5.ext:
# Extracting rectangle_2ca8eea5 into rectangle_2ca8eea5.ext:
# Extracting compass_de42ad8e into compass_de42ad8e.ext:
# Extracting rectangle_de42ad8e into rectangle_de42ad8e.ext:
# Extracting compass_1513e44c into compass_1513e44c.ext:
# Extracting rectangle_1513e44c into rectangle_1513e44c.ext:
# Extracting compass_2ca8eea5$1 into compass_2ca8eea5$1.ext:
# Extracting rectangle_2ca8eea5$1 into rectangle_2ca8eea5$1.ext:
# Extracting compass_71fba8f9$1 into compass_71fba8f9$1.ext:
# Extracting rectangle_71fba8f9$1 into rectangle_71fba8f9$1.ext:
# Extracting stdp into stdp.ext:
# stdp: 106 errors
# --- ANTENNA CHECK COMPLETED ---
#
#
# [SUCCESS] Succesfull antena verification for  'stdp'. No violations.

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted: L_route_9c9fed4d.ext
# Deleted: rectangle_b92fd4c8.ext
# Deleted: compass_de42ad8e.ext
# Deleted: straight_route_d6a45d2e.ext
# Deleted: L_route_7418b0f0.ext
# Deleted: rectangle_2ca8eea5$1.ext
# Deleted: L_route_a4b8e0be.ext
# Deleted: straight_route_d412d36f.ext
# Deleted: L_route_97c034e0.ext
# Deleted: L_route_b70fb8b9.ext
# Deleted: rectangle_09b029e7$1.ext
# Deleted: L_route_f3c37f7c.ext
# Deleted: straight_route_4f7b53c4.ext
# Deleted: L_route_15a0f388.ext
# Deleted: rectangle_e2d3d538.ext
# Deleted: L_route_84b89d48.ext
# Deleted: c_route_5d5d9dce.ext
# Deleted: c_route_27a9af3f.ext
# Deleted: rectangle_d564bdc4.ext
# Deleted: L_route_c02104a2.ext
# Deleted: L_route_250364aa.ext
# Deleted: L_route_de1ddc48.ext
# Deleted: via_stack_9a7c1b9a.ext
# Deleted: compass_b92fd4c8$1.ext
# Deleted: L_route_e80ba176.ext
# Deleted: L_route_bf2dc457.ext
# Deleted: L_route_5dfb3b8e.ext
# Deleted: via_stack_a2e89513$1.ext
# Deleted: straight_route_bef7e062.ext
# Deleted: stdp.ext
# Deleted: L_route_a26b7849.ext
# Deleted: compass_09b029e7.ext
# Deleted: straight_route_5d9b008b.ext
# Deleted: straight_route_0e3b015b.ext
# Deleted: xm12.ext
# Deleted: c_route_74e2d13e.ext
# Deleted: c_route_51338640.ext
# Deleted: L_route_f95e00f1.ext
# Deleted: xm8.ext
# Deleted: rectangle_d564bdc4$1.ext
# Deleted: via_stack_a2e89513$2.ext
# Deleted: L_route_7d1d6490.ext
# Deleted: compass_7c30efbc.ext
# Deleted: rectangle_71fba8f9.ext
# Deleted: via_stack_9a7c1b9a$1.ext
# Deleted: via_stack_a2e89513$3.ext
# Deleted: xm9.ext
# Deleted: cpot.ext
# Deleted: compass_71fba8f9$1.ext
# Deleted: xm17.ext
# Deleted: c_route_8c2c3aa6.ext
# Deleted: straight_route_40ea4316.ext
# Deleted: L_route_7fbace87.ext
# Deleted: via_stack_a2e89513$7.ext
# Deleted: via_stack_a2e89513$10.ext
# Deleted: straight_route_87d64758.ext
# Deleted: compass_5f24ff68$1.ext
# Deleted: via_stack_a2e89513$11.ext
# Deleted: via_stack_a2e89513$6.ext
# Deleted: rectangle_5f24ff68.ext
# Deleted: c_route_7f62e8aa.ext
# Deleted: xm16.ext
# Deleted: L_route_2a0d08f8.ext
# Deleted: compass_7c30efbc$1.ext
# Deleted: via_stack_a2e89513$4.ext
# Deleted: rectangle_1513e44c.ext
# Deleted: rectangle_2ca8eea5.ext
# Deleted: straight_route_912067d4.ext
# Deleted: via_stack_a2e89513$5.ext
# Deleted: via_stack_a2e89513.ext
# Deleted: straight_route_278724c2.ext
# Deleted: compass_a9fdc1e6.ext
# Deleted: L_route_36e59ea2.ext
# Deleted: compass_5f24ff68.ext
# Deleted: xm2.ext
# Deleted: via_stack_a2e89513$8.ext
# Deleted: L_route_9fbd38b8.ext
# Deleted: rectangle_b92fd4c8$1.ext
# Deleted: via_stack_a2e89513$9.ext
# Deleted: xm3.ext
# Deleted: L_route_24694a7c.ext
# Deleted: rectangle_a9fdc1e6.ext
# Deleted: L_route_78eb8817.ext
# Deleted: cdep.ext
# Deleted: L_route_02ccd910.ext
# Deleted: c_route_58d7b39c.ext
# Deleted: L_route_fd8021c9.ext
# Deleted: straight_route_b12ee564.ext
# Deleted: xm1.ext
# Deleted: via_stack_a2e89513$20.ext
# Deleted: straight_route_627dacd5.ext
# Deleted: compass_2ca8eea5.ext
# Deleted: straight_route_dcd74ac0.ext
# Deleted: compass_1513e44c.ext
# Deleted: via_stack_a2e89513$21.ext
# Deleted: L_route_d7736fb3.ext
# Deleted: rectangle_09b029e7.ext
# Deleted: compass_09b029e7$1.ext
# Deleted: xm4.ext
# Deleted: L_route_eecda21a.ext
# Deleted: via_stack_a2e89513$18.ext
# Deleted: xm5.ext
# Deleted: L_route_473cd7a1.ext
# Deleted: c_route_2c32f15c.ext
# Deleted: straight_route_e98796db.ext
# Deleted: xm7.ext
# Deleted: compass_71fba8f9.ext
# Deleted: L_route_d08c40b4.ext
# Deleted: L_route_a3d28efd.ext
# Deleted: rectangle_7c30efbc.ext
# Deleted: compass_2ca8eea5$1.ext
# Deleted: L_route_47d51595.ext
# Deleted: c_route_c0d8624c.ext
# Deleted: rectangle_7c30efbc$1.ext
# Deleted: c_route_907243ac.ext
# Deleted: compass_d564bdc4.ext
# Deleted: L_route_b110259d.ext
# Deleted: xmcm_chain_3.ext
# Deleted: cw.ext
# Deleted: L_route_eb435deb.ext
# Deleted: c_route_8d402972.ext
# Deleted: xmcm_chain_2.ext
# Deleted: c_route_d8df7a08.ext
# Deleted: compass_e2d3d538.ext
# Deleted: c_route_827fc2f0.ext
# Deleted: xmcm_chain_0.ext
# Deleted: straight_route_dfafd98e.ext
# Deleted: straight_route_806dfc06.ext
# Deleted: L_route_a5af8734.ext
# Deleted: rectangle_5f24ff68$1.ext
# Deleted: xmcm_chain_1.ext
# Deleted: xmcm_1.ext
# Deleted: compass_d564bdc4$1.ext
# Deleted: xmcm_chain_4.ext
# Deleted: rectangle_de42ad8e.ext
# Deleted: compass_b92fd4c8.ext
# Deleted: rectangle_71fba8f9$1.ext
# Deleted: c_route_ee66a350.ext
# Deleted: L_route_8d468e06.ext
# Deleted: L_route_80b7825c.ext
# Deleted: straight_route_d4eb442b.ext
# Deleted: straight_route_1d1f080b.ext
