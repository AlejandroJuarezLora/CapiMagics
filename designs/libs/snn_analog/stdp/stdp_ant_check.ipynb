# %%
import os
from pathlib import Path
import tempfile
import subprocess

magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name = "stdp"
path_to_dir = "/foss/designs/libs/snn_analog/stdp/"

gds_path = path_to_dir + f"{design_name}.gds"

    
magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell

# Se requiere la extracción previa para calcular las áreas de metal y difusión
extract do local
extract all

# Ejecución de la verificación de antena
antennacheck debug
puts "--- ANTENNA CHECK COMPLETED ---"
exit
"""

with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name

# Se eliminó la coma sobrante al final de la cadena de comando
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'"
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "stdp".
# Reading "via_stack_a2e89513".
# Reading "via_stack_a2e89513$3".
# Reading "L_route_6e3be213".
# Reading "straight_route_24562756".
# Reading "xm5".
# Reading "straight_route_092a4ad2".
# Reading "compass_e1e0dc30".
# Reading "L_route_38533d52".
# Reading "c_route_199965fa".
# Reading "L_route_06197600".
# Reading "straight_route_6d3c66b0".
# Reading "xm12".
# Reading "L_route_4f3c70f4".
# Reading "c_route_bbe04714".
# Reading "L_route_7d1d6490".
# Reading "rectangle_e1e0dc30$1".
# Reading "c_route_9807e6d5".
# Reading "L_route_3cdf85a1".
# Reading "L_route_c9fb0e3d".
# Reading "L_route_dce49672".
# Reading "c_route_1007e5b2".
# Reading "via_stack_a2e89513$7".
# Reading "straight_route_d5067a8a".
# Reading "L_route_faba338a".
# Reading "xmcm_chain_3".
# Reading "xm9".
# Reading "xmcm_1".
# Reading "L_route_fec25d93".
# Reading "straight_route_912067d4".
# Reading "straight_route_705995df".
# Reading "xm16".
# Reading "rectangle_e1e0dc30".
# Reading "via_stack_a2e89513$4".
# Reading "c_route_bc6a5a09".
# Reading "c_route_922411dc".
# Reading "via_stack_a2e89513$18".
# Reading "xm4".
# Reading "straight_route_627dacd5".
# Reading "L_route_6543e741".
# Reading "via_stack_a2e89513$20".
# Reading "straight_route_d4774138".
# Reading "via_stack_a2e89513$1".
# Reading "L_route_a798b3d0".
# Reading "L_route_8e188866".
# Reading "xm3".
# Reading "L_route_998ac79d".
# Reading "straight_route_f7e6d5a0".
# Reading "c_route_827fc2f0".
# Reading "L_route_6425f4a2".
# Reading "via_stack_a2e89513$8".
# Reading "L_route_5fe24f68".
# Reading "c_route_b76bcd8f".
# Reading "c_route_c4a522dd".
# Reading "cpot".
# Reading "xmcm_chain_0".
# Reading "straight_route_9fc870a4".
# Reading "xm8".
# Reading "L_route_7b25d91e".
# Reading "L_route_4436be73".
# Reading "L_route_c6cd091b".
# Reading "xm17".
# Reading "via_stack_a2e89513$5".
# Reading "via_stack_a2e89513$11".
# Reading "straight_route_49f0316f".
# Reading "straight_route_e28c56ab".
# Reading "L_route_014589f3".
# Reading "xm7".
# Reading "L_route_db7ab175".
# Reading "cdep".
# Reading "straight_route_c83b0ff1".
# Reading "via_stack_a2e89513$21".
# Reading "L_route_9f043be2".
# Reading "c_route_008b6267".
# Reading "straight_route_637371fd".
# Reading "compass_e1e0dc30$1".
# Reading "via_stack_a2e89513$2".
# Reading "straight_route_a2a9bccc".
# Reading "xmcm_chain_4".
# Reading "xm2".
# Reading "L_route_cb47f8ce".
# Reading "straight_route_d4f73f3d".
# Reading "c_route_1b76b2b8".
# Reading "L_route_0995c6ab".
# Reading "via_stack_a2e89513$9".
# Reading "L_route_2b0e2e30".
# Reading "L_route_d39df9b7".
# Reading "straight_route_1c947539".
# Reading "L_route_85fa3bf1".
# Reading "straight_route_7172faa1".
# Reading "c_route_007c8831".
# Reading "xmcm_chain_1".
# Reading "xm1".
# Reading "L_route_98ba129e".
# Reading "L_route_497c1123".
# Reading "via_stack_a2e89513$6".
# Reading "c_route_93ceb544".
# Reading "L_route_92a6feee".
# Reading "via_stack_a2e89513$10".
# Reading "L_route_7278c89b".
# Reading "xmcm_chain_2".
# Reading "c_route_7558d5fc".
# Reading "L_route_6747071c".
# Reading "cw".
# Extracting straight_route_912067d4 into straight_route_912067d4.ext:
# Extracting xm4 into xm4.ext:
# Extracting via_stack_a2e89513$20 into via_stack_a2e89513$20.ext:
# Extracting xm3 into xm3.ext:
# Extracting straight_route_9fc870a4 into straight_route_9fc870a4.ext:
# Extracting L_route_06197600 into L_route_06197600.ext:
# Extracting xm12 into xm12.ext:
# Extracting xm9 into xm9.ext:
# Extracting straight_route_627dacd5 into straight_route_627dacd5.ext:
# Extracting via_stack_a2e89513$21 into via_stack_a2e89513$21.ext:
# Extracting xmcm_chain_1 into xmcm_chain_1.ext:
# Extracting xmcm_chain_2 into xmcm_chain_2.ext:
# Extracting xmcm_chain_0 into xmcm_chain_0.ext:
# Extracting L_route_5fe24f68 into L_route_5fe24f68.ext:
# Extracting straight_route_d4774138 into straight_route_d4774138.ext:
# Extracting L_route_fec25d93 into L_route_fec25d93.ext:
# Extracting xmcm_1 into xmcm_1.ext:
# Extracting xmcm_chain_3 into xmcm_chain_3.ext:
# Extracting L_route_3cdf85a1 into L_route_3cdf85a1.ext:
# Extracting via_stack_a2e89513 into via_stack_a2e89513.ext:
# Extracting c_route_7558d5fc into c_route_7558d5fc.ext:
# Extracting L_route_7278c89b into L_route_7278c89b.ext:
# Extracting L_route_cb47f8ce into L_route_cb47f8ce.ext:
# Extracting straight_route_24562756 into straight_route_24562756.ext:
# Extracting L_route_38533d52 into L_route_38533d52.ext:
# Extracting L_route_c9fb0e3d into L_route_c9fb0e3d.ext:
# Extracting via_stack_a2e89513$4 into via_stack_a2e89513$4.ext:
# Extracting L_route_6543e741 into L_route_6543e741.ext:
# Extracting via_stack_a2e89513$11 into via_stack_a2e89513$11.ext:
# Extracting straight_route_e28c56ab into straight_route_e28c56ab.ext:
# Extracting straight_route_d4f73f3d into straight_route_d4f73f3d.ext:
# Extracting straight_route_1c947539 into straight_route_1c947539.ext:
# Extracting straight_route_7172faa1 into straight_route_7172faa1.ext:
# Extracting via_stack_a2e89513$3 into via_stack_a2e89513$3.ext:
# Extracting straight_route_705995df into straight_route_705995df.ext:
# Extracting c_route_bc6a5a09 into c_route_bc6a5a09.ext:
# Extracting via_stack_a2e89513$8 into via_stack_a2e89513$8.ext:
# Extracting L_route_db7ab175 into L_route_db7ab175.ext:
# Extracting straight_route_c83b0ff1 into straight_route_c83b0ff1.ext:
# Extracting c_route_93ceb544 into c_route_93ceb544.ext:
# Extracting c_route_9807e6d5 into c_route_9807e6d5.ext:
# Extracting c_route_922411dc into c_route_922411dc.ext:
# Extracting c_route_1b76b2b8 into c_route_1b76b2b8.ext:
# Extracting via_stack_a2e89513$5 into via_stack_a2e89513$5.ext:
# Extracting c_route_c4a522dd into c_route_c4a522dd.ext:
# Extracting c_route_827fc2f0 into c_route_827fc2f0.ext:
# Extracting L_route_6e3be213 into L_route_6e3be213.ext:
# Extracting c_route_b76bcd8f into c_route_b76bcd8f.ext:
# Extracting L_route_6425f4a2 into L_route_6425f4a2.ext:
# Extracting xm16 into xm16.ext:
# Extracting L_route_92a6feee into L_route_92a6feee.ext:
# Extracting straight_route_092a4ad2 into straight_route_092a4ad2.ext:
# Extracting L_route_4f3c70f4 into L_route_4f3c70f4.ext:
# Extracting xmcm_chain_4 into xmcm_chain_4.ext:
# Extracting L_route_0995c6ab into L_route_0995c6ab.ext:
# Extracting c_route_007c8831 into c_route_007c8831.ext:
# Extracting L_route_6747071c into L_route_6747071c.ext:
# Extracting L_route_faba338a into L_route_faba338a.ext:
# Extracting straight_route_a2a9bccc into straight_route_a2a9bccc.ext:
# Extracting via_stack_a2e89513$6 into via_stack_a2e89513$6.ext:
# Extracting cdep into cdep.ext:
# Extracting compass_e1e0dc30$1 into compass_e1e0dc30$1.ext:
# Extracting rectangle_e1e0dc30$1 into rectangle_e1e0dc30$1.ext:
# Extracting L_route_7d1d6490 into L_route_7d1d6490.ext:
# Extracting c_route_1007e5b2 into c_route_1007e5b2.ext:
# Extracting straight_route_d5067a8a into straight_route_d5067a8a.ext:
# Extracting xm2 into xm2.ext:
# Extracting xm1 into xm1.ext:
# Extracting via_stack_a2e89513$9 into via_stack_a2e89513$9.ext:
# Extracting xm7 into xm7.ext:
# Extracting via_stack_a2e89513$1 into via_stack_a2e89513$1.ext:
# Extracting L_route_497c1123 into L_route_497c1123.ext:
# Extracting L_route_2b0e2e30 into L_route_2b0e2e30.ext:
# Extracting straight_route_f7e6d5a0 into straight_route_f7e6d5a0.ext:
# Extracting straight_route_6d3c66b0 into straight_route_6d3c66b0.ext:
# Extracting xm8 into xm8.ext:
# Extracting L_route_8e188866 into L_route_8e188866.ext:
# Extracting xm5 into xm5.ext:
# Extracting via_stack_a2e89513$10 into via_stack_a2e89513$10.ext:
# Extracting via_stack_a2e89513$18 into via_stack_a2e89513$18.ext:
# Extracting L_route_998ac79d into L_route_998ac79d.ext:
# Extracting via_stack_a2e89513$2 into via_stack_a2e89513$2.ext:
# Extracting straight_route_637371fd into straight_route_637371fd.ext:
# Extracting xm17 into xm17.ext:
# Extracting L_route_85fa3bf1 into L_route_85fa3bf1.ext:
# Extracting L_route_7b25d91e into L_route_7b25d91e.ext:
# Extracting via_stack_a2e89513$7 into via_stack_a2e89513$7.ext:
# Extracting L_route_98ba129e into L_route_98ba129e.ext:
# Extracting L_route_4436be73 into L_route_4436be73.ext:
# Extracting L_route_dce49672 into L_route_dce49672.ext:
# Extracting c_route_199965fa into c_route_199965fa.ext:
# Extracting L_route_014589f3 into L_route_014589f3.ext:
# Extracting c_route_008b6267 into c_route_008b6267.ext:
# Extracting L_route_d39df9b7 into L_route_d39df9b7.ext:
# Extracting straight_route_49f0316f into straight_route_49f0316f.ext:
# Extracting L_route_c6cd091b into L_route_c6cd091b.ext:
# Extracting cpot into cpot.ext:
# Extracting L_route_a798b3d0 into L_route_a798b3d0.ext:
# Extracting L_route_9f043be2 into L_route_9f043be2.ext:
# Extracting compass_e1e0dc30 into compass_e1e0dc30.ext:
# Extracting rectangle_e1e0dc30 into rectangle_e1e0dc30.ext:
# Extracting c_route_bbe04714 into c_route_bbe04714.ext:
# Extracting cw into cw.ext:
# Extracting stdp into stdp.ext:
# stdp: 122 errors
# --- ANTENNA CHECK COMPLETED ---

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
